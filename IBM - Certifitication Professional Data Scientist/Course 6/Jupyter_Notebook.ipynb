# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem
# ![2-title.png](Assets/img2.png)

# %% [markdown]
# ## In this notebook, Data Science Tools and Ecosystem are summarized.
# ![3-intro.png](Assets/img3.png)

# %% [markdown]
# **Some of the popular languages that Data Scientists use are:**
# 1. Python
# 2. R
# 3. C
# 4. C++

# %% [markdown]
# ![4-dslanguages.png](Assets/img4.png)

# %% [markdown]
# **Some of the commonly used libraries used by Data Scientists include:**
# 1. Pandas
# 2. Numpy
# 3. Matplotlib
# 4. Seaborn
# 5. Scikit-learn
# 6. Tensorflow
# 7. Keras

# %% [markdown]
# ![5-dslibraries.png](Assets/img5.png)

# %% [markdown]
# **Data Science Tools**
# <br>
# |**Categories**|**Tools**|
# |--------------|---------|
# |Data Management|MySQL,PostgreSQL,MongoDB|
# |Data Integration|Apache Airflow, Kubeflow, Apache Kafka|
# |Model Deployment|Seldon, Redhat Openshift, Tensorflow Lite|

# %% [markdown]
# ![6-dstools.png](Assets/img6.png)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %% [markdown]
# ![7-introarithmetic.png](Assets/img7.png)

# %%
#This a simple arithmetic expression to mutiply then add integers
(3*4)+5
# Out:
# 17

# %% [markdown]
# ![8-multiplyandaddintegers.png](Assets/img8.png)

# %%
#This will convert 200 minutes to hours by diving by 60
mnt = 200
hrs = 60
convert = mnt/hrs
print (mnt,"minutes is equals ",convert,"Hours")
# Out:
# 200 minutes is equals  3.3333333333333335 Hours

# %% [markdown]
# ![9-hourstominutes.png](Assets/img9.png)

# %% [markdown]
# **Objectives:**
# <br>
# Libraries for Data Scienctist:
# 1. Scientific Computing
#     - Pandas : Data Structures & Tools
#     - Numpy : Array & Matrices
# <br>
# <br>
# 2. Visualization
#     - Matplotlib : Plots & graphs
#     - Seaborn : Plots(heatmps,violin plots, time series)
# <br>
# <br>
# 3. Machine Learning & Deep Learning
#     - Scikit-learn : Regression, Classification, Clustering
#     - Keras : Deep Learning Neural Networkss
# <br>
# <br>
# 4. Deep Learning
#     - Tensorflow : Production & Deployment
#     - PyTorch : Deep Learning Regression, Classification

# %% [markdown]
# ![10-objectives.png](Assets/img10.png)

# %% [markdown]
# ## Author
#
#
# Tirta Rumy Swandaru

# %% [markdown]
# ![11-authordetails.png](Assets/img11.png)

# %% [markdown]
# ![1-notebook.png](Assets/img13.png)
